# %%
from Data_transform.data_transform import interface

# %%
interface.data_csv_file("dados_fake.csv")

# %%
interface.db_arquive("CACHE_DADOS/dados_fake.db")

# %%
interface.printar_tipos_de_dados()
# Out:
# Tipos de dados na coluna:
#
#
# (0, 'ID', 'TEXT', 0, None, 0)
# (1, 'Nome', 'TEXT', 0, None, 0)
# (2, 'Idade', 'TEXT', 0, None, 0)
# (3, 'Salário', 'TEXT', 0, None, 0)

# %%
interface.remover_coluna(["ID", "Nome"])

# %%
interface.printar_tipos_de_dados()
# Out:
# Tipos de dados na coluna:
#
#
# (0, 'Idade', 'REAL', 0, None, 0)
# (1, 'Salário', 'REAL', 0, None, 0)

# %%
interface.converter_valores()

# %%
interface.plotar_mapa_de_correlacao("Salário")
